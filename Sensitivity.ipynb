# %%
# %matplotlib inline
import pylab as P
from numpy import *
import sensitivity as S

print S.test_view(S.ShapeTriangle)
# Out:
# Figure(480x320)

# %%
print S.test_view(S.ShapeGrid)
# Out:
# Figure(480x320)

# %%
R_Triangle = reload(S).pnp_experiments(S.ShapeTriangle, 100,linspace(0.1,5,10), linspace(0,2.,4))
R_Grid = reload(S).pnp_experiments(S.ShapeGrid, 100,linspace(0.1,5,10), linspace(0,2.,4))

# %%
reload(S).show_pnp_experiments(R_Grid)
P.gcf().set_size_inches(18,6)

# %%
S.show_pnp_experiments(R_Triangle)
P.gcf().set_size_inches(18,6)
